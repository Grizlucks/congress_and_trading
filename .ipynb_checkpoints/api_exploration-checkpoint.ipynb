# %% [markdown]
# ### Exploring the Alpha Vantage API
#
# https://www.alphavantage.co/documentation/
#
# Is it worth using for the project?

# %%
import requests
import json
import pandas as pd
import numpy as np
import os

# %%
# obscuring API key
api_key = os.environ.get("ALPHA_VANTAGE_API_KEY")

# testing with IBM 
ticker = "IBM"

# %%
ibm_data = pd.read_csv(f"https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY_ADJUSTED&symbol={ticker}&apikey={api_key}&datatype=csv")
# Out:
#       timestamp    open    high       low   close  adjusted close     volume  \
# 0    2021-11-09  125.05  127.29  119.9000  120.85        120.8500   42612508
# 1    2021-10-29  141.00  146.00  124.6200  125.10        117.9972  144097758
# 2    2021-09-30  139.98  140.57  132.7800  138.93        131.0420   76644238
# 3    2021-08-31  141.45  144.70  137.2100  140.34        132.3719   69687056
# 4    2021-07-30  146.96  147.50  136.2089  140.96        131.4307  110625907
# ..          ...     ...     ...       ...     ...             ...        ...
# 259  2000-04-28  120.00  128.00  101.2500  111.50         64.6714  168464800
# 260  2000-03-31  102.00  128.25   99.5000  118.37         68.6561  194329000
# 261  2000-02-29  112.37  119.75  100.9400  102.75         59.5963  133524400
# 262  2000-01-31  112.44  124.75  109.6200  112.25         65.0407  175259600
# 263  1999-12-31  102.56  122.12  102.2500  107.87         62.5028  158626300
#
#      dividend amount
# 0               1.64
# ...

# %% [markdown]
# This API could be good for comparing gains made on certain days for congressmen/women of interest after events that we hypothesize would be cause for them to sell off of "insider information".
#
# NOTE: The API does not give us enough calls (500 per day) to check every unique stock present in the congressmen dataset. Would still be worth using in instances where we expect a certain level of gain or something similar.
